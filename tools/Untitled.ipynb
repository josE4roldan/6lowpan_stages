# %%
import pandas as pd


    
    
def reorder(dataframe):
    dataframe = dataframe[['timestamp','packetLength','info',
                   'sourceIP','destinationIP','protocol','Source Port','Destination Port',
                   'MQTT.flags','MQTT.message','MQTT.topic','MQTT.messageLength']]
    return dataframe


def numtodic(strnum):
    nuevodic = {}
    if(str(strnum[0])=="-1"):
        return "-1"
    nuevodic["MQTT.messageLength"] = int(strnum[0:2],16)
    if (str(strnum[2:4])=="00"):
        nuevodic["info"]="ADVERTISE"
    elif("01"==str(strnum[2:4])):
        nuevodic["info"]="SEARCHGW"
    elif("02"==str(strnum[2:4])):
        nuevodic["info"]="GWINFO"
    elif("04"==str(strnum[2:4])):
        nuevodic["MQTT.flags"]=str(strnum[4:6])
        nuevodic["info"]="TYPE:CONNECT;PROTOCOLID:"+str(strnum[6:10])+";DURATION:"+str(strnum[10:14])+";CLIENTID:"+str(strnum[14:len(strnum)])
    elif("05"==str(strnum[2:4])):
        nuevodic["info"]="CONNACK"
    elif("06"==str(strnum[2:4])):
        nuevodic["info"]="WILLTOPICREQ"
    elif("07"==str(strnum[2:4])):
        nuevodic["info"]="WILLTOPIC"
        nuevodic["MQTT.flags"]=str(strnum[4:6])
        nuevodic["info"]="TYPE:WILLTOPIC;WILLTOPIC:"+str(strnum[6:len(strnum)])
    elif("08"==str(strnum[2:4])):
        nuevodic["info"]="WILLMSGREQ"
    elif("09"==str(strnum[2:4])):
        nuevodic["info"]="WILLMSG"
    elif("0a"==str(strnum[2:4])):
        nuevodic["MQTT.topic"]=str(strnum[4:8])
        nuevodic["info"]="TYPE:REGISTER;MESSAGEID:"+str(strnum[8:12])+";TOPICNAME:"+str(bytes.fromhex(str(strnum[12:(len(strnum))])).decode('utf-8'))
    elif("0b"==str(strnum[2:4])):
        nuevodic["info"]="REGACK"
    elif("0c"==str(strnum[2:4])):
        nuevodic["MQTT.flags"]=str(strnum[4:6])
        nuevodic["MQTT.topic"]=str(strnum[6:10])
        nuevodic["info"]="TYPE:PUBLISH;MESSAGEID:"+str(strnum[10:14])
        nuevodic["MQTT.message"]=bytes.fromhex(str(strnum[14:(len(strnum))])).decode('utf-8')
    elif("0d"==str(strnum[2:4])):
        nuevodic["info"]="PUBACK"
    elif("0e"==str(strnum[2:4])):
        nuevodic["info"]="PUBCOMP"
    elif("0f"==str(strnum[2:4])):
        nuevodic["info"]="PUBREC"
    elif("10"==str(strnum[2:4])):
        nuevodic["info"]="PUBREL"
    elif("12"==str(strnum[2:4])):
        nuevodic["MQTT.flags"]=str(strnum[4:6])
        nuevodic["info"]="TYPE:SUBSCRIBE;MESSAGEID:"+str(strnum[6:10])
        nuevodic["MQTT.topic"]=str(strnum[10:(len(strnum))])
    elif("13"==str(strnum[2:4])):
        nuevodic["info"]="SUBACK"
    elif("14"==str(strnum[2:4])):
        nuevodic["info"]="UNSUBSCRIBE"
    elif("15"==str(strnum[2:4])):
        nuevodic["info"]="UNSUBACK"
    elif("16"==str(strnum[2:4])):
        nuevodic["info"]="TYPE:PINGREQ"+";CLIENTID:"+str(strnum[4:(len(strnum))])
    elif("17"==str(strnum[2:4])):
        nuevodic["info"]="PINGRESP"
    elif("18"==str(strnum[2:4])):
        nuevodic["info"]="TYPE:DISCONNECT"+";DURATION:"+str(strnum[4:8])
    elif("1a"==str(strnum[2:4])):
        nuevodic["info"]="WILLTOPICUPD"
    elif("1b"==str(strnum[2:4])):
        nuevodic["info"]="WILLTOPICRESP"
    elif("1c"==str(strnum[2:4])):
        nuevodic["info"]="WILLMSGUPD"
    elif("1d"==str(strnum[2:4])):
        nuevodic["info"]="WILLMSGRESP"
    elif("1e"==str(strnum[2:4])):
        nuevodic["MQTT.flags"]=str(strnum[4:6])
        nuevodic["info"]="TYPE:SUB_WILDCAR;MESSAGEID:"+tr(strnum[6:10])
        nuevodic["MQTT.topic"]=str(strnum[10:(len(strnum))])
    return nuevodic


df_conv = pd.read_csv("normal_stage_mqttsn.csv",error_bad_lines=False)

# %%
int("17",16)
# Out:
# 23

# %%
df_conv.fillna("-1",inplace=True)

# %%
df_conv
# Out:
#          No.     timestamp              sourceIP         destinationIP  \
# 0          1  1.547546e+09  fe80::212:7402:2:202              ff02::1a
# 1          2  1.547546e+09  fe80::212:7406:6:606              ff02::1a
# 2          3  1.547546e+09  fe80::212:7401:1:101              ff02::1a
# 3          4  1.547546e+09  fe80::212:7409:9:909              ff02::1a
# 4          5  1.547546e+09  fe80::212:7405:5:505              ff02::1a
# 5          6  1.547546e+09  fe80::212:740d:d:d0d              ff02::1a
# 6          7  1.547546e+09  fe80::212:740a:a:a0a              ff02::1a
# 7          8  1.547546e+09  fe80::212:740e:e:e0e              ff02::1a
# 8          9  1.547546e+09  fe80::212:7403:3:303              ff02::1a
# 9         10  1.547546e+09  fe80::212:7407:7:707              ff02::1a
# 10        11  1.547546e+09  fe80::212:740b:b:b0b              ff02::1a
# 11        12  1.547546e+09  fe80::212:740f:f:f0f              ff02::1a
# 12        13  1.547546e+09  fe80::212:7404:4:404              ff02::1a
# 13        14  1.547546e+09  fe80::212:7408:8:808              ff02::1a
# 14        15  1.547546e+09  fe80::212:740c:c:c0c              ff02::1a
# 15        16  1.547546e+09  fe80::212:7402:2:202              ff02::1a
# 16        17  1.547546e+09  fe80::212:7406:6:606              ff02::1a
# 17        18  1.547546e+09  fe80::212:7401:1:101              ff02::1a
# 18        19  1.547546e+09  fe80::212:7409:9:909              ff02::1a
# 19        20  1.547546e+09  fe80::212:7405:5:505              ff02::1a
# 20        21  1.547546e+09  fe80::212:740d:d:d0d              ff02::1a
# 21        22  1.547546e+09  fe80::212:740a:a:a0a              ff02::1a
# 22        23  1.547546e+09  fe80::212:740e:e:e0e              ff02::1a
# 23        24  1.547546e+09  fe80::212:7403:3:303              ff02::1a
# 24        25  1.547546e+09  fe80::212:7407:7:707              ff02::1a
# 25        26  1.547546e+09  fe80::212:740b:b:b0b              ff02::1a
# 26        27  1.547546e+09  fe80::212:740f:f:f0f              ff02::1a
# 27        28  1.547546e+09  fe80::212:7404:4:404              ff02::1a
# 28        29  1.547546e+09  fe80::212:7408:8:808              ff02::1a
# 29        30  1.547546e+09  fe80::212:740c:c:c0c              ff02::1a
# ...      ...           ...                   ...                   ...
# 53245  53246  1.547546e+09      ::212:7407:7:707                   ::1
# 53246  53247  1.547546e+09      ::212:740e:e:e0e                   ::1
# 53247  53248  1.547546e+09      ::212:740f:f:f0f                   ::1
# 53248  53249  1.547546e+09      ::212:740a:a:a0a                   ::1
# 53249  53250  1.547546e+09      ::212:7405:5:505                   ::1
# 53250  53251  1.547546e+09      ::212:740c:c:c0c                   ::1
# 53251  53252  1.547546e+09               aaaa::1  aaaa::212:7402:2:202
# 53252  53253  1.547546e+09                    -1                    -1
# 53253  53254  1.547546e+09               aaaa::1  aaaa::212:7409:9:909
# 53254  53255  1.547546e+09                    -1                    -1
# 53255  53256  1.547546e+09      ::212:7409:9:909                   ::1
# 53256  53257  1.547546e+09      ::212:7405:5:505                   ::1
# 53257  53258  1.547546e+09      ::212:740d:d:d0d                   ::1
# 53258  53259  1.547546e+09      ::212:7403:3:303                   ::1
# 53259  53260  1.547546e+09      ::212:7408:8:808                   ::1
# 53260  53261  1.547546e+09      ::212:740b:b:b0b                   ::1
# 53261  53262  1.547546e+09      ::212:7402:2:202                   ::1
# 53262  53263  1.547546e+09      ::212:7406:6:606                   ::1
# 53263  53264  1.547546e+09      ::212:740d:d:d0d                   ::1
# 53264  53265  1.547546e+09               aaaa::1  aaaa::212:740d:d:d0d
# 53265  53266  1.547546e+09                    -1                    -1
# 53266  53267  1.547546e+09      ::212:7404:4:404                   ::1
# 53267  53268  1.547546e+09      ::212:7407:7:707                   ::1
# 53268  53269  1.547546e+09      ::212:7401:1:101                   ::1
# 53269  53270  1.547546e+09      ::212:7407:7:707                   ::1
# 53270  53271  1.547546e+09      ::212:740e:e:e0e                   ::1
# 53271  53272  1.547546e+09      ::212:740f:f:f0f                   ::1
# 53272  53273  1.547546e+09      ::212:7403:3:303                   ::1
# 53273  53274  1.547546e+09               aaaa::1  aaaa::212:7407:7:707
# 53274  53275  1.547546e+09                    -1                    -1
#
#             protocol  packetLength Source Port Destination Port  \
# 0             ICMPv6            64          -1               -1
# 1             ICMPv6            64          -1               -1
# 2             ICMPv6            64          -1               -1
# 3             ICMPv6            64          -1               -1
# 4             ICMPv6            64          -1               -1
# 5             ICMPv6            64          -1               -1
# 6             ICMPv6            64          -1               -1
# 7             ICMPv6            64          -1               -1
# 8             ICMPv6            64          -1               -1
# 9             ICMPv6            64          -1               -1
# 10            ICMPv6            64          -1               -1
# 11            ICMPv6            64          -1               -1
# 12            ICMPv6            64          -1               -1
# 13            ICMPv6            64          -1               -1
# 14            ICMPv6            64          -1               -1
# 15            ICMPv6            64          -1               -1
# 16            ICMPv6            64          -1               -1
# 17            ICMPv6            64          -1               -1
# 18            ICMPv6            64          -1               -1
# 19            ICMPv6            64          -1               -1
# 20            ICMPv6            64          -1               -1
# 21            ICMPv6            64          -1               -1
# 22            ICMPv6            64          -1               -1
# 23            ICMPv6            64          -1               -1
# 24            ICMPv6            64          -1               -1
# 25            ICMPv6            64          -1               -1
# 26            ICMPv6            64          -1               -1
# 27            ICMPv6            64          -1               -1
# 28            ICMPv6            64          -1               -1
# 29            ICMPv6            64          -1               -1
# ...              ...           ...         ...              ...
# 53245            UDP            74        1884             1884
# 53246            UDP            74        1884             1884
# 53247            UDP            74        1884             1884
# 53248            UDP            74        1884             1884
# 53249            UDP            69        1884             1884
# 53250            UDP            74        1884             1884
# 53251            UDP            82        1884             1884
# 53252  IEEE 802.15.4             5          -1               -1
# 53253            UDP            82        1884             1884
# 53254  IEEE 802.15.4             5          -1               -1
# 53255            UDP            74        1884             1884
# 53256            UDP            74        1884             1884
# 53257            UDP            74        1884             1884
# 53258            UDP            74        1884             1884
# 53259            UDP            74        1884             1884
# 53260            UDP            74        1884             1884
# 53261            UDP            74        1884             1884
# 53262            UDP            74        1884             1884
# 53263            UDP            69        1884             1884
# 53264            UDP            82        1884             1884
# 53265  IEEE 802.15.4             5          -1               -1
# 53266            UDP            74        1884             1884
# 53267            UDP            69        1884             1884
# 53268            UDP            74        1884             1884
# 53269            UDP            74        1884             1884
# 53270            UDP            74        1884             1884
# 53271            UDP            74        1884             1884
# 53272            UDP            69        1884             1884
# 53273            UDP            82        1884             1884
# 53274  IEEE 802.15.4             5          -1               -1
#
#                                                  Data Source  \
# 0                                                  -1     -1
# 1                                                  -1     -1
# 2                                                  -1     -1
# 3                                                  -1     -1
# 4                                                  -1     -1
# 5                                                  -1     -1
# 6                                                  -1     -1
# 7                                                  -1     -1
# 8                                                  -1     -1
# 9                                                  -1     -1
# 10                                                 -1     -1
# 11                                                 -1     -1
# 12                                                 -1     -1
# 13                                                 -1     -1
# 14                                                 -1     -1
# 15                                                 -1     -1
# 16                                                 -1     -1
# 17                                                 -1     -1
# 18                                                 -1     -1
# 19                                                 -1     -1
# 20                                                 -1     -1
# 21                                                 -1     -1
# 22                                                 -1     -1
# 23                                                 -1     -1
# 24                                                 -1     -1
# 25                                                 -1     -1
# 26                                                 -1     -1
# 27                                                 -1     -1
# 28                                                 -1     -1
# 29                                                 -1     -1
# ...                                               ...    ...
# 53245  170c100001000068656c6c6f20616464723a3037303700     -1
# 53246  170c100001000068656c6c6f20616464723a3045304500     -1
# 53247  170c100001000068656c6c6f20616464723a3046304600     -1
# 53248  170c100001000068656c6c6f20616464723a3041304100     -1
# 53249            121630303132373430353030303530353035     -1
# 53250  170c100001000068656c6c6f20616464723a3043304300     -1
# 53251                                            0217     -1
# 53252                                              -1     -1
# 53253                                            0217     -1
# 53254                                              -1     -1
# 53255  170c100001000068656c6c6f20616464723a3039303900     -1
# 53256  170c100001000068656c6c6f20616464723a3035303500     -1
# 53257  170c100001000068656c6c6f20616464723a3044304400     -1
# 53258  170c100001000068656c6c6f20616464723a3033303300     -1
# 53259  170c100001000068656c6c6f20616464723a3038303800     -1
# 53260  170c100001000068656c6c6f20616464723a3042304200     -1
# 53261  170c100001000068656c6c6f20616464723a3032303200     -1
# 53262  170c100001000068656c6c6f20616464723a3036303600     -1
# 53263            121630303132373430443030304430443044     -1
# 53264                                            0217     -1
# 53265                                              -1     -1
# 53266  170c100001000068656c6c6f20616464723a3034303400     -1
# 53267            121630303132373430373030303730373037     -1
# 53268  170c100001000068656c6c6f20616464723a3031303100     -1
# 53269  170c100001000068656c6c6f20616464723a3037303700     -1
# 53270  170c100001000068656c6c6f20616464723a3045304500     -1
# 53271  170c100001000068656c6c6f20616464723a3046304600     -1
# 53272            121630303132373430333030303330333033     -1
# 53273                                            0217     -1
# 53274                                              -1     -1
#
#                                                info
# 0      RPL Control (DODAG Information Solicitation)
# 1      RPL Control (DODAG Information Solicitation)
# 2      RPL Control (DODAG Information Solicitation)
# 3      RPL Control (DODAG Information Solicitation)
# 4      RPL Control (DODAG Information Solicitation)
# 5      RPL Control (DODAG Information Solicitation)
# 6      RPL Control (DODAG Information Solicitation)
# 7      RPL Control (DODAG Information Solicitation)
# 8      RPL Control (DODAG Information Solicitation)
# 9      RPL Control (DODAG Information Solicitation)
# 10     RPL Control (DODAG Information Solicitation)
# 11     RPL Control (DODAG Information Solicitation)
# 12     RPL Control (DODAG Information Solicitation)
# 13     RPL Control (DODAG Information Solicitation)
# 14     RPL Control (DODAG Information Solicitation)
# 15     RPL Control (DODAG Information Solicitation)
# 16     RPL Control (DODAG Information Solicitation)
# 17     RPL Control (DODAG Information Solicitation)
# 18     RPL Control (DODAG Information Solicitation)
# 19     RPL Control (DODAG Information Solicitation)
# 20     RPL Control (DODAG Information Solicitation)
# 21     RPL Control (DODAG Information Solicitation)
# 22     RPL Control (DODAG Information Solicitation)
# 23     RPL Control (DODAG Information Solicitation)
# 24     RPL Control (DODAG Information Solicitation)
# 25     RPL Control (DODAG Information Solicitation)
# 26     RPL Control (DODAG Information Solicitation)
# 27     RPL Control (DODAG Information Solicitation)
# 28     RPL Control (DODAG Information Solicitation)
# 29     RPL Control (DODAG Information Solicitation)
# ...                                             ...
# 53245                          1884  >  1884 Len=23
# 53246                          1884  >  1884 Len=23
# 53247                          1884  >  1884 Len=23
# 53248                          1884  >  1884 Len=23
# 53249                          1884  >  1884 Len=18
# 53250                          1884  >  1884 Len=23
# 53251                           1884  >  1884 Len=2
# 53252                                           Ack
# 53253                           1884  >  1884 Len=2
# 53254                                           Ack
# 53255                          1884  >  1884 Len=23
# 53256                          1884  >  1884 Len=23
# 53257                          1884  >  1884 Len=23
# 53258                          1884  >  1884 Len=23
# 53259                          1884  >  1884 Len=23
# 53260                          1884  >  1884 Len=23
# 53261                          1884  >  1884 Len=23
# 53262                          1884  >  1884 Len=23
# 53263                          1884  >  1884 Len=18
# 53264                           1884  >  1884 Len=2
# 53265                                           Ack
# 53266                          1884  >  1884 Len=23
# 53267                          1884  >  1884 Len=18
# 53268                          1884  >  1884 Len=23
# 53269                          1884  >  1884 Len=23
# 53270                          1884  >  1884 Len=23
# 53271                          1884  >  1884 Len=23
# 53272                          1884  >  1884 Len=18
# 53273                           1884  >  1884 Len=2
# 53274                                           Ack
#
# [53275 rows x 11 columns]

# %%
for i, row in df_conv.iterrows():
    if(str(row['Data'][0:2])=="0e"):
        print(i)
# Out:
# 165
# 168
# 171
# 174
# 177
# 181
# 184
# 188
# 192
# 195
# 198
# 211
# 214
# 215
# 216
# 219
# 222
# 225
# 228
# 231
# 266
# 284
# 292
# 296
# 299
# 307
# 310
# 313
# 316
# 321
# 324
# 328
# 331
# 336
# 339
# 342
# 362
# 365
# 368
# 371
# 372
# 375
# 379
# 382
# 384
# 387
# 388
# 393
# 397
# 400
# 404
# 435
# 437
# 439
# 442
# 451
# 456
# 459
# 463
# 468
# 481
# 493
# 496
# 497
# 499
# 502
# 503
# 506
# 511
# 516
# 522
# 525
# 533
# 538
# 578
# 581
# 584
# 585
# 586
# 590
# 595
# 602
# 659
# 708
# 715
# 766
# 771
# 778
# 790
# 799
# 803
# 899
# 903
# 907
# 910
# 956
# 961
# 962
# 972
# 978
# 982
# 985
# 991
# 995
# 1002
# 1007
# 1024
# 1056
# 1058
# 1062
# 1069
# 1075
# 1078
# 1086
# 1090
# 1094
# 1146
# 1177
# 1215
# 1291
# 1568
# 1573
# 1581
# 1586
# 1591
# 1600

# %%
df_conv.iloc[165]
# Out:
# No.                                          166
# timestamp                            1.54755e+09
# sourceIP                        ::212:740d:d:d0d
# destinationIP                                ::1
# protocol                                     UDP
# packetLength                                  65
# Source Port                                 1884
# Destination Port                            1884
# Data                0e0a000000012f746f7069635f31
# Source                                        -1
# info                        1884  >  1884 Len=14
# Name: 165, dtype: object

# %%
df_conv['Data'] = df_conv["Data"].apply(lambda x: numtodic(str(x)))

# %%
df_conv.iloc[165]
# Out:
# No.                                                               166
# timestamp                                                 1.54755e+09
# sourceIP                                             ::212:740d:d:d0d
# destinationIP                                                     ::1
# protocol                                                          UDP
# packetLength                                                       65
# Source Port                                                      1884
# Destination Port                                                 1884
# Data                {'MQTT.messageLength': 14, 'MQTT.topic': '0000...
# Source                                                             -1
# info                                             1884  >  1884 Len=14
# Name: 165, dtype: object

# %%
df_conv["MQTT.flags"]=df_conv["Data"].apply(lambda x: x["MQTT.flags"] if "MQTT.flags" in x else -1)
df_conv["MQTT.message"]=df_conv["Data"].apply(lambda x: x["MQTT.message"] if "MQTT.message" in x else -1)
df_conv["MQTT.messageLength"]=df_conv["Data"].apply(lambda x: x["MQTT.messageLength"] if "MQTT.messageLength" in x else -1)
df_conv["MQTT.topic"]=df_conv["Data"].apply(lambda x: x["MQTT.topic"] if "MQTT.topic" in x else -1)
df_conv["info"]=df_conv["Data"].apply(lambda x: x["info"] if "info" in x else -1)
#del df_conv["Data"]
df_conv=reorder(df_conv)
#df_conv.to_csv("parsed_file.csv", quoting=2, index=False)

# %%
df_conv.iloc[165]
# Out:
# timestamp                                                 1.54755e+09
# packetLength                                                       65
# info                  TYPE:REGISTER;MESSAGEID:0001;TOPICNAME:/topic_1
# sourceIP                                             ::212:740d:d:d0d
# destinationIP                                                     ::1
# protocol                                                          UDP
# Source Port                                                      1884
# Destination Port                                                 1884
# MQTT.flags                                                         -1
# MQTT.message                                                       -1
# MQTT.topic                                                       0000
# MQTT.messageLength                                                 14
# Name: 165, dtype: object

# %%
df_conv[df_conv['MQTT.messageLength']>-1]
# Out:
#           timestamp  packetLength  \
# 136    1.547546e+09            73
# 137    1.547546e+09            73
# 138    1.547546e+09            73
# 139    1.547546e+09            73
# 140    1.547546e+09            73
# 142    1.547546e+09            73
# 143    1.547546e+09            73
# 145    1.547546e+09            73
# 146    1.547546e+09            73
# 148    1.547546e+09            73
# 149    1.547546e+09            73
# 153    1.547546e+09            73
# 154    1.547546e+09            73
# 159    1.547546e+09            73
# 161    1.547546e+09            73
# 163    1.547546e+09            83
# 165    1.547546e+09            65
# 166    1.547546e+09            83
# 168    1.547546e+09            65
# 169    1.547546e+09            83
# 171    1.547546e+09            65
# 172    1.547546e+09            62
# 174    1.547546e+09            65
# 175    1.547546e+09            62
# 177    1.547546e+09            65
# 179    1.547546e+09            62
# 181    1.547546e+09            65
# 182    1.547546e+09            62
# 184    1.547546e+09            65
# 186    1.547546e+09            62
# ...             ...           ...
# 53241  1.547546e+09            74
# 53242  1.547546e+09            74
# 53243  1.547546e+09            69
# 53244  1.547546e+09            74
# 53245  1.547546e+09            74
# 53246  1.547546e+09            74
# 53247  1.547546e+09            74
# 53248  1.547546e+09            74
# 53249  1.547546e+09            69
# 53250  1.547546e+09            74
# 53251  1.547546e+09            82
# 53253  1.547546e+09            82
# 53255  1.547546e+09            74
# 53256  1.547546e+09            74
# 53257  1.547546e+09            74
# 53258  1.547546e+09            74
# 53259  1.547546e+09            74
# 53260  1.547546e+09            74
# 53261  1.547546e+09            74
# 53262  1.547546e+09            74
# 53263  1.547546e+09            69
# 53264  1.547546e+09            82
# 53266  1.547546e+09            74
# 53267  1.547546e+09            69
# 53268  1.547546e+09            74
# 53269  1.547546e+09            74
# 53270  1.547546e+09            74
# 53271  1.547546e+09            74
# 53272  1.547546e+09            69
# 53273  1.547546e+09            82
#
#                                                     info          sourceIP  \
# 136    TYPE:CONNECT;PROTOCOLID:0100;DURATION:0530;CLI...  ::212:7408:8:808
# 137    TYPE:CONNECT;PROTOCOLID:0100;DURATION:0530;CLI...  ::212:740b:b:b0b
# 138    TYPE:CONNECT;PROTOCOLID:0100;DURATION:0530;CLI...  ::212:7402:2:202
# 139    TYPE:CONNECT;PROTOCOLID:0100;DURATION:0530;CLI...  ::212:7406:6:606
# 140    TYPE:CONNECT;PROTOCOLID:0100;DURATION:0530;CLI...  ::212:7404:4:404
# 142    TYPE:CONNECT;PROTOCOLID:0100;DURATION:0530;CLI...  ::212:7401:1:101
# 143    TYPE:CONNECT;PROTOCOLID:0100;DURATION:0530;CLI...  ::212:7407:7:707
# 145    TYPE:CONNECT;PROTOCOLID:0100;DURATION:0530;CLI...  ::212:740e:e:e0e
# 146    TYPE:CONNECT;PROTOCOLID:0100;DURATION:0530;CLI...  ::212:740f:f:f0f
# 148    TYPE:CONNECT;PROTOCOLID:0100;DURATION:0530;CLI...  ::212:740a:a:a0a
# 149    TYPE:CONNECT;PROTOCOLID:0100;DURATION:0530;CLI...  ::212:740c:c:c0c
# 153    TYPE:CONNECT;PROTOCOLID:0100;DURATION:0530;CLI...  ::212:7409:9:909
# 154    TYPE:CONNECT;PROTOCOLID:0100;DURATION:0530;CLI...  ::212:7405:5:505
# 159    TYPE:CONNECT;PROTOCOLID:0100;DURATION:0530;CLI...  ::212:740d:d:d0d
# 161    TYPE:CONNECT;PROTOCOLID:0100;DURATION:0530;CLI...  ::212:7403:3:303
# 163                                              CONNACK           aaaa::1
# 165      TYPE:REGISTER;MESSAGEID:0001;TOPICNAME:/topic_1  ::212:740d:d:d0d
# 166                                              CONNACK           aaaa::1
# 168      TYPE:REGISTER;MESSAGEID:0001;TOPICNAME:/topic_1  ::212:7407:7:707
# 169                                              CONNACK           aaaa::1
# 171      TYPE:REGISTER;MESSAGEID:0001;TOPICNAME:/topic_1  ::212:7403:3:303
# 172                                               REGACK               ::1
# 174      TYPE:REGISTER;MESSAGEID:0002;TOPICNAME:/topic_2  ::212:740d:d:d0d
# 175                                               REGACK               ::1
# 177      TYPE:REGISTER;MESSAGEID:0002;TOPICNAME:/topic_2  ::212:7403:3:303
# 179                                               REGACK               ::1
# 181      TYPE:REGISTER;MESSAGEID:0002;TOPICNAME:/topic_2  ::212:7407:7:707
# 182                                               REGACK               ::1
# 184      TYPE:REGISTER;MESSAGEID:0003;TOPICNAME:/topic_3  ::212:740d:d:d0d
# 186                                               REGACK               ::1
# ...                                                  ...               ...
# 53241                        TYPE:PUBLISH;MESSAGEID:0000  ::212:7406:6:606
# 53242                        TYPE:PUBLISH;MESSAGEID:0000  ::212:7404:4:404
# 53243  TYPE:PINGREQ;CLIENTID:303031323734304330303043...  ::212:740c:c:c0c
# 53244                        TYPE:PUBLISH;MESSAGEID:0000  ::212:7401:1:101
# 53245                        TYPE:PUBLISH;MESSAGEID:0000  ::212:7407:7:707
# 53246                        TYPE:PUBLISH;MESSAGEID:0000  ::212:740e:e:e0e
# 53247                        TYPE:PUBLISH;MESSAGEID:0000  ::212:740f:f:f0f
# 53248                        TYPE:PUBLISH;MESSAGEID:0000  ::212:740a:a:a0a
# 53249  TYPE:PINGREQ;CLIENTID:303031323734303530303035...  ::212:7405:5:505
# 53250                        TYPE:PUBLISH;MESSAGEID:0000  ::212:740c:c:c0c
# 53251                                           PINGRESP           aaaa::1
# 53253                                           PINGRESP           aaaa::1
# 53255                        TYPE:PUBLISH;MESSAGEID:0000  ::212:7409:9:909
# 53256                        TYPE:PUBLISH;MESSAGEID:0000  ::212:7405:5:505
# 53257                        TYPE:PUBLISH;MESSAGEID:0000  ::212:740d:d:d0d
# 53258                        TYPE:PUBLISH;MESSAGEID:0000  ::212:7403:3:303
# 53259                        TYPE:PUBLISH;MESSAGEID:0000  ::212:7408:8:808
# 53260                        TYPE:PUBLISH;MESSAGEID:0000  ::212:740b:b:b0b
# 53261                        TYPE:PUBLISH;MESSAGEID:0000  ::212:7402:2:202
# 53262                        TYPE:PUBLISH;MESSAGEID:0000  ::212:7406:6:606
# 53263  TYPE:PINGREQ;CLIENTID:303031323734304430303044...  ::212:740d:d:d0d
# 53264                                           PINGRESP           aaaa::1
# 53266                        TYPE:PUBLISH;MESSAGEID:0000  ::212:7404:4:404
# 53267  TYPE:PINGREQ;CLIENTID:303031323734303730303037...  ::212:7407:7:707
# 53268                        TYPE:PUBLISH;MESSAGEID:0000  ::212:7401:1:101
# 53269                        TYPE:PUBLISH;MESSAGEID:0000  ::212:7407:7:707
# 53270                        TYPE:PUBLISH;MESSAGEID:0000  ::212:740e:e:e0e
# 53271                        TYPE:PUBLISH;MESSAGEID:0000  ::212:740f:f:f0f
# 53272  TYPE:PINGREQ;CLIENTID:303031323734303330303033...  ::212:7403:3:303
# 53273                                           PINGRESP           aaaa::1
#
#               destinationIP protocol Source Port Destination Port MQTT.flags  \
# 136                     ::1      UDP        1884             1884         04
# 137                     ::1      UDP        1884             1884         04
# 138                     ::1      UDP        1884             1884         04
# 139                     ::1      UDP        1884             1884         04
# 140                     ::1      UDP        1884             1884         04
# 142                     ::1      UDP        1884             1884         04
# 143                     ::1      UDP        1884             1884         04
# 145                     ::1      UDP        1884             1884         04
# 146                     ::1      UDP        1884             1884         04
# 148                     ::1      UDP        1884             1884         04
# 149                     ::1      UDP        1884             1884         04
# 153                     ::1      UDP        1884             1884         04
# 154                     ::1      UDP        1884             1884         04
# 159                     ::1      UDP        1884             1884         04
# 161                     ::1      UDP        1884             1884         04
# 163    aaaa::212:740d:d:d0d      UDP        1884             1884         -1
# 165                     ::1      UDP        1884             1884         -1
# 166    aaaa::212:7407:7:707      UDP        1884             1884         -1
# 168                     ::1      UDP        1884             1884         -1
# 169    aaaa::212:7403:3:303      UDP        1884             1884         -1
# 171                     ::1      UDP        1884             1884         -1
# 172        ::212:740d:d:d0d      UDP        1884             1884         -1
# 174                     ::1      UDP        1884             1884         -1
# 175        ::212:7403:3:303      UDP        1884             1884         -1
# 177                     ::1      UDP        1884             1884         -1
# 179        ::212:7407:7:707      UDP        1884             1884         -1
# 181                     ::1      UDP        1884             1884         -1
# 182        ::212:740d:d:d0d      UDP        1884             1884         -1
# 184                     ::1      UDP        1884             1884         -1
# 186        ::212:7407:7:707      UDP        1884             1884         -1
# ...                     ...      ...         ...              ...        ...
# 53241                   ::1      UDP        1884             1884         10
# 53242                   ::1      UDP        1884             1884         10
# 53243                   ::1      UDP        1884             1884         -1
# 53244                   ::1      UDP        1884             1884         10
# 53245                   ::1      UDP        1884             1884         10
# 53246                   ::1      UDP        1884             1884         10
# 53247                   ::1      UDP        1884             1884         10
# 53248                   ::1      UDP        1884             1884         10
# 53249                   ::1      UDP        1884             1884         -1
# 53250                   ::1      UDP        1884             1884         10
# 53251  aaaa::212:7402:2:202      UDP        1884             1884         -1
# 53253  aaaa::212:7409:9:909      UDP        1884             1884         -1
# 53255                   ::1      UDP        1884             1884         10
# 53256                   ::1      UDP        1884             1884         10
# 53257                   ::1      UDP        1884             1884         10
# 53258                   ::1      UDP        1884             1884         10
# 53259                   ::1      UDP        1884             1884         10
# 53260                   ::1      UDP        1884             1884         10
# 53261                   ::1      UDP        1884             1884         10
# 53262                   ::1      UDP        1884             1884         10
# 53263                   ::1      UDP        1884             1884         -1
# 53264  aaaa::212:740d:d:d0d      UDP        1884             1884         -1
# 53266                   ::1      UDP        1884             1884         10
# 53267                   ::1      UDP        1884             1884         -1
# 53268                   ::1      UDP        1884             1884         10
# 53269                   ::1      UDP        1884             1884         10
# 53270                   ::1      UDP        1884             1884         10
# 53271                   ::1      UDP        1884             1884         10
# 53272                   ::1      UDP        1884             1884         -1
# 53273  aaaa::212:7407:7:707      UDP        1884             1884         -1
#
#            MQTT.message MQTT.topic  MQTT.messageLength
# 136                  -1         -1                  22
# 137                  -1         -1                  22
# 138                  -1         -1                  22
# 139                  -1         -1                  22
# 140                  -1         -1                  22
# 142                  -1         -1                  22
# 143                  -1         -1                  22
# 145                  -1         -1                  22
# 146                  -1         -1                  22
# 148                  -1         -1                  22
# 149                  -1         -1                  22
# 153                  -1         -1                  22
# 154                  -1         -1                  22
# 159                  -1         -1                  22
# 161                  -1         -1                  22
# 163                  -1         -1                   3
# 165                  -1       0000                  14
# 166                  -1         -1                   3
# 168                  -1       0000                  14
# 169                  -1         -1                   3
# 171                  -1       0000                  14
# 172                  -1         -1                   7
# 174                  -1       0000                  14
# 175                  -1         -1                   7
# 177                  -1       0000                  14
# 179                  -1         -1                   7
# 181                  -1       0000                  14
# 182                  -1         -1                   7
# 184                  -1       0000                  14
# 186                  -1         -1                   7
# ...                 ...        ...                 ...
# 53241  hello addr:0606       0001                  23
# 53242  hello addr:0404       0001                  23
# 53243                -1         -1                  18
# 53244  hello addr:0101       0001                  23
# 53245  hello addr:0707       0001                  23
# 53246  hello addr:0E0E       0001                  23
# 53247  hello addr:0F0F       0001                  23
# 53248  hello addr:0A0A       0001                  23
# 53249                -1         -1                  18
# 53250  hello addr:0C0C       0001                  23
# 53251                -1         -1                   2
# 53253                -1         -1                   2
# 53255  hello addr:0909       0001                  23
# 53256  hello addr:0505       0001                  23
# 53257  hello addr:0D0D       0001                  23
# 53258  hello addr:0303       0001                  23
# 53259  hello addr:0808       0001                  23
# 53260  hello addr:0B0B       0001                  23
# 53261  hello addr:0202       0001                  23
# 53262  hello addr:0606       0001                  23
# 53263                -1         -1                  18
# 53264                -1         -1                   2
# 53266  hello addr:0404       0001                  23
# 53267                -1         -1                  18
# 53268  hello addr:0101       0001                  23
# 53269  hello addr:0707       0001                  23
# 53270  hello addr:0E0E       0001                  23
# 53271  hello addr:0F0F       0001                  23
# 53272                -1         -1                  18
# 53273                -1         -1                   2
#
# [45951 rows x 12 columns]

# %%
df_conv.to_csv("parsed_file.csv", quoting=2, index=False)
